# %% [markdown]
# # 선형 회귀 분석, 다중 회귀 분석

# %% [markdown]
# - 다중 회귀 방정식은 데이터 행렬 X의 차원p에 따라 달라진다.
# - 일반적으로 우리가 알고있는 선형 회귀 방적식은 데이터 행렬 X의 차원이 1인경우 이다.
# - 행렬 X의 차원이 p일 경우 다중 회귀 방정식은 다음과 같다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - i는 데이터 행렬 X에서 행의 번호를 의미한다. - 즉, 몇 번째 데이터인가를 의미한다.
# - 여기서 입실론은 평균이 베타0인 확률변수이다.
# - 위 식을 행렬과 벡터로 일반화하여 나타내면 아래와 같다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 다항 회귀 분석

# %% [markdown]
# - 데이터 행렬 X의 차원이 1일 때 다항 회귀 방정식은 다음과 같다.
# - 단순 회귀 방정식은 직선으로만 표기가 가능하지만, 다항 회귀 방정식은 곡선으로 표현이 가능하여 더 유연히 fitting이 가능하다
# - 하지만 항의 갯수를 너무 크게 키우면 분산이 커져 overfitting의 문제가 생길 수 있다.(다중 회귀 방정식도 같은 문제가 발생한다)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - quad fit이 x의 제곱항까지 있는 다항 회귀 방정식이고
# - cubic fit이 x의 세제곱항까지 있는 다항 회귀 방정식이다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lasso, Ridge, Elastic Regularization

# %% [markdown]
# - 다중 회귀 방정식과 다항 회귀 방정식에서 언급 되었던 항이 늘어나 계수의 수가 늘어남으로 인해 생기는 overfitting의 문제를 어떻게 해결할 수 있을까?
# - overffiting을 줄이기 위한 방법은 다양하지만 여기서는 손실함수에 제약조건을 주어서 정규화를 하는 방법을 활용한다.

# %% [markdown]
# - 먼저 L1 Norm을 활용하여 제약을 두는 Lasso 회귀는 다음과 같다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 위 식은 계수 벡터 베타의 L2노름이 상수 t보다 작게 유지 하며 최소화를 하는 베타를 찾는 것이 목적인 식이다.
# - 위 식을 라그랑지 승수법을 활용하여 아래와 같은 식으로 유도할 수 있다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 람다는 t에 반비례하며, 람다가 커질 수록 제약이 커진다고 생각하면 된다.
# - Ridge는 베타의 L1 노름이 아니라 L2 노름을 제약조건으로 준 것으로 제약 공간의 모양이 달라진다.
# - Ridge와 Lasso의 제약 공간에 대한 설명은 아래의 그림을 참고하자.

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# - 첫 번째 그림은 Lasso
# - 두 번째 그림은 Ridge
# - 세 번째 그림은 elasticnet

# %% [markdown]
# - lasso는 제약공간의 특징상 공간의 축에서 최적의 점이 생길 가능성이 높아져 변수를 선택하는 효과를 보여주기도 한다.
# - elasticnet은 아래와 같이 lasso와 ridge를 알파를 활용하여 tradeoff 관계로 만들어 두 방법의 규제를 balance있게 활용하도록 한다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. MAE, MSE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - MAE는 예측과 실제값의 차이를 L1 norm을 활용하여 나타낸다.
# - MAE는 MSE보다 조금 더 직관적인고 정확한 거리를 준다고 할 수 있다.
# - 하지만 MAE는 미분이 불가능하여 최적화를 위한 손실함수로 사용하기가 어렵다
#
# - MSE는 예측과 실제값의 차이를 L2 norm을 활용하여 나타내다.
# - MSE는 미분이 가능하여 회귀에 대한 손실함수로 활용할 수 있다.
# - 또한 MSE는 차이를 제곱함에따라 손실이 커짐에 따라 손실의 차이가 더 커지게 되어 큰 손실에 대해 가중치를 주는 효과를 낸다.

# %% [markdown]
# # 경사하강법

# %% [markdown]
# - 경사하강법은 계수 벡터 w에 대한 손실함수 L(w)를 최소화 하기 위한 dw의 방향이 L(w)의 그래디언트 벡터의 반대 방향임을 활용하여 최적화하는 수치적 최적화 방법 중 하나이다.
# - 아래는 계수 벡터를 x라고 했을 때 f(x)를 최적화하도록 x를 update하는 식이다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 위 식에서 알파는 학습률 이며, 그레디언트 벡터의 방향으로 얼마나 더 x를 이동시킬 것인가에 대한 정도를 의미한다.
# - 학습률 알파는 최적화해야할 hyperparameter이다.
# - 학습률 알파가 적당히 크면 학습 속도가 빠르고 Local Minimum에 쉽게 빠지지 않을 수 있지만,
# - 학습률 알파가 너무 크게 되면 손실함수값이 진동하며 학습이 되지 않을 수 있다.
# - 학습률 알파가 너무 작으면 학습 속도가 너무 느리거나 Local Minimum에 쉽게 빠질 수 있다.
# - 때문에 처음에는 학습률을 크게하여 Local minimum에 쉽게 빠지지 않으며 빠르게 하강하고 점점 학습을 진행하며 학습률을 줄여나가며 더 섬세하게 global minimum을 찾게끔 한다. - 이러한 방법을 적응형 경사하강법이라고도 부른다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 정규방정식

# %% [markdown]
# - 정규방정식은 선형회귀에서 손실함수인 MSE의 극속값을 찾기위해 해석적인 방법으로 해를 구한 식이다.
# - 정규방정식을 유도하는 과정은 아래와 같다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 위에서 벡터 b는 정답 데이터 벡터 y를 의미하고, 행렬 A는 데이터 행렬 X를 의미하고, 벡터 x는 계수 벡터 w를 의미한다.
# - 두 번째 줄은 계수 벡터 x로 편미분한 값이 0이 되는 식을 구한 것이다.
# - 마지막 줄로 갈때 주의할 점은 행렬A와 행렬A_Transpose의 행렬곱에 대한 determinant가 0이 되면 안된다. 즉, 가역행렬이어야 한다.
# - 하지만 데이터 행렬 A의 차원이 너무 크거나 다중공선성이 큰 경우 A_transpose*A 의 determinant가 0에 가까워져 정규방정식을 도출해내지 못하게 된다.
# - 위와 같은 경우가 나오는 이유는 현실에서는 데이터의 모든 차원이 서로 독립인 데이터가 나오기 힘들기 때문이다.
# - 때문에 해석적인 방법보다 조금 더 일반적으로 활용이 가능한 수치해석 방법인 경사하강법 기반의 최적화를 통해 최적의 해를 구하게 된다.
